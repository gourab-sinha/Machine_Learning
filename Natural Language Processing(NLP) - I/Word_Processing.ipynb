# %% [markdown]
# <a href="https://colab.research.google.com/github/gourab-sinha/Machine_Learning/blob/master/Natural%20Language%20Processing(NLP)%20-%20I/Word_Processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sample_text = "Does this thing really work? Lets see."

# %%
import nltk
nltk.download('punkt')

from nltk.tokenize import sent_tokenize, word_tokenize
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
sent_tokenize(sample_text)
# Out:
# ['Does this thing really work?', 'Lets see.']

# %%
words = word_tokenize(sample_text)

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
# ...

# %%
clean_words = [w for w in words if not w in stop_words]

# %%
clean_words
# Out:
# ['Does', 'thing', 'really', 'work', '?', 'Lets', 'see', '.']

# %%
import string
punctuation = list(string.punctuation)

# %%
from nltk.stem import PorterStemmer

# %%
stem_words =["play","playing","player","briefly"]
ps = PorterStemmer()
stemmed_words = [ps.stem(w) for w in stem_words]
stemmed_words
# Out:
# ['play', 'play', 'player', 'briefli']

# %% [markdown]
# ##### Parts of speech

# %%
from nltk import pos_tag

# %%
nltk.download('state_union')
nltk.download('averaged_perceptron_tagger')

from nltk.corpus import state_union
# Out:
# [nltk_data] Downloading package state_union to /root/nltk_data...
# [nltk_data]   Package state_union is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %%
text = state_union.raw("2006-GWBush.txt")

# %%
pos = pos_tag(word_tokenize(text))
pos
# Out:
# [('PRESIDENT', 'NNP'),
#  ('GEORGE', 'NNP'),
#  ('W.', 'NNP'),
#  ('BUSH', 'NNP'),
#  ("'S", 'POS'),
#  ('ADDRESS', 'NNP'),
#  ('BEFORE', 'IN'),
#  ('A', 'NNP'),
#  ('JOINT', 'NNP'),
#  ('SESSION', 'NNP'),
#  ('OF', 'IN'),
#  ('THE', 'NNP'),
#  ('CONGRESS', 'NNP'),
#  ('ON', 'NNP'),
#  ('THE', 'NNP'),
#  ('STATE', 'NNP'),
#  ('OF', 'IN'),
#  ('THE', 'NNP'),
#  ('UNION', 'NNP'),
#  ('January', 'NNP'),
#  ('31', 'CD'),
#  (',', ','),
#  ('2006', 'CD'),
#  ('THE', 'NNP'),
#  ('PRESIDENT', 'NNP'),
#  (':', ':'),
#  ('Thank', 'NNP'),
#  ('you', 'PRP'),
#  ('all', 'DT'),
#  ('.', '.'),
#  ('Mr.', 'NNP'),
#  ('Speaker', 'NNP'),
#  (',', ','),
#  ('Vice', 'NNP'),
#  ('President', 'NNP'),
#  ('Cheney', 'NNP'),
#  (',', ','),
#  ('members', 'NNS'),
#  ('of', 'IN'),
#  ('Congress', 'NNP'),
#  (',', ','),
#  ('members', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Supreme', 'NNP'),
#  ('Court', 'NNP'),
#  ('and', 'CC'),
#  ('diplomatic', 'JJ'),
#  ('corps', 'NN'),
#  (',', ','),
# ...

# %%
text = "raj went for a walk"
pos = pos_tag(word_tokenize(text))
pos
# Out:
# [('raj', 'NN'), ('went', 'VBD'), ('for', 'IN'), ('a', 'DT'), ('walk', 'NN')]

# %%
text = "This painting is beautiful."
pos = pos_tag(word_tokenize(text))
pos
# Out:
# [('This', 'DT'),
#  ('painting', 'NN'),
#  ('is', 'VBZ'),
#  ('beautiful', 'JJ'),
#  ('.', '.')]

# %%
text = "I have been painting since morning."
pos = pos_tag(word_tokenize(text))
pos
# Out:
# [('I', 'PRP'),
#  ('have', 'VBP'),
#  ('been', 'VBN'),
#  ('painting', 'VBG'),
#  ('since', 'IN'),
#  ('morning', 'NN'),
#  ('.', '.')]

# %%
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %%
lemmatizer = WordNetLemmatizer()

# %%
lemmatizer.lemmatize("better",pos = "a")
# Out:
# 'good'

# %%
lemmatizer.lemmatize("painting",pos = "v") # Verb
# Out:
# 'paint'

# %%
lemmatizer.lemmatize("painting",pos = "n") # Noun
# Out:
# 'painting'

# %%
def get_simple_pos(tag):
  if tag.startswith('J'):
    return wordnet.ADJ
  elif tag.startswith('V'):
    return wordnet.VERB
  elif tag.startswith('N'):
    return wordnet.NOUN
  elif tag.startswith('R'):
    return wordnet.ADV
  else:
    return wordnet.NOUN
