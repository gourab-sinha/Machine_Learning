# %% [markdown]
# <a href="https://colab.research.google.com/github/gourab-sinha/Machine_Learning/blob/master/Principal%20Component%20Analysis(PCA)/PCA_3D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %%
np.random.seed(2343243)

# %%
mean_vec1 = np.array([0,0,0])
cov_mat1 = np.array([[1,0,0],[0,1,0],[0,0,1]])
class1 = np.random.multivariate_normal(mean_vec1,cov_mat1,100)

# %%
mean_vec2 = np.array([0,0,0])
cov_mat2 = np.array([[1,0,0],[0,1,0],[0,0,1]])
class2 = np.random.multivariate_normal(mean_vec2,cov_mat2,100)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D,proj3d

fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111,projection='3d')
ax.plot(class1[:,0],class1[:,1],class1[:,2],'o')
ax.plot(class2[:,0],class2[:,1],class2[:,2],'^')
plt.show()

# %%
all_data = np.concatenate((class1,class2))
pca = PCA(n_components=2)
# pca = PCA()
transform_data = pca.fit_transform(all_data)
transform_data
# Out:
# array([[ 5.54071564e-01, -1.73171241e-01],
#        [-1.02432773e+00, -9.57950835e-01],
#        [-8.00611340e-01,  6.90088529e-01],
#        [-1.04180365e+00,  1.70422479e+00],
#        [ 1.68603420e-01, -4.75707195e-01],
#        [ 1.16802749e+00, -5.35258646e-01],
#        [ 8.52716861e-01, -9.54503899e-01],
#        [ 2.94327093e-01, -4.53890971e-01],
#        [-1.12206482e+00,  5.20498573e-01],
#        [ 2.25109356e-01, -4.46970959e-01],
#        [ 6.85812963e-01,  1.30953027e+00],
#        [ 4.54323905e-01, -1.00154622e+00],
#        [-3.69075541e-01, -5.00256865e-01],
#        [ 9.49995383e-02,  1.80004929e-01],
#        [-3.96033739e-01, -1.35700421e+00],
#        [ 2.19518481e-01,  1.70711639e-01],
#        [ 3.53144342e-01, -1.56493634e+00],
#        [ 1.50494046e+00, -1.98063064e+00],
#        [ 6.10831292e-01, -1.45599715e+00],
#        [-1.59818776e+00,  5.22157387e-02],
#        [-3.75975643e-01,  2.68830284e-01],
#        [-1.86954538e-01,  3.09878662e-01],
# ...

# %%
pca.components_
# Out:
# array([[-0.65568085,  0.52870481,  0.53903047],
#        [ 0.4293886 ,  0.84833241, -0.30977014]])

# %%
plt.plot(transform_data[:100,0],transform_data[:100,1],"o")
plt.plot(transform_data[100:,0],transform_data[100:,1],"^")

# %%
cov = np.cov(all_data.T)
eigen_val,eigen_vec = np.linalg.eig(cov)
eigen_val,eigen_vec
# Out:
# (array([1.10804445, 0.80243042, 0.86642486]),
#  array([[-0.65568085,  0.62105399, -0.4293886 ],
#         [ 0.52870481, -0.02834319, -0.84833241],
#         [ 0.53903047,  0.78325514,  0.30977014]]))

# %%
eigen_val_with_vector = []
for i in range(len(eigen_vec)):
  val = eigen_val[i]
  vec = eigen_vec[i,i]
  eigen_val_with_vector.append([val,vec])

eigen_val_with_vector
# Out:
# [[1.1080444482876461, -0.6556808466403828],
#  [0.8024304218344885, -0.02834319128074768],
#  [0.8664248640563518, 0.30977014379425255]]
